# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 1. a)

# %%
R = np.linspace(0.0, 30.0, 100.0)  
mu1 = 2.5*np.log10(np.exp(-R**(1./1.)))
plt.plot(R, mu1)

# %%
mu2 = 2.5*np.log10(np.exp(-R**(1./2.)))
plt.plot(R, mu2)

# %%
mu3 = 2.5*np.log10(np.exp(-R**(1./3.)))
plt.plot(R, mu3)

# %%
mu4 = 2.5*np.log10(np.exp(-R**(1./4.)))
plt.plot(R, mu4)

# %% [markdown]
# ### 1. b)

# %% [markdown]
# ### $$ \int_0^R e^{-R} dR = \frac{1}{2} $$

# %% [markdown]
# ### R = ln(2)

# %% [markdown]
# ### 1. c)

# %% [markdown]
# ### $$ \frac{\int_0^1 e^{-R} dR}{1} = 0.6321 $$

# %% [markdown]
# ### 2. a)

# %% [raw]
# I would classify this galaxy as an Sa type galaxy because there is no bar and the two spiral arms are clearly distinct.

# %% [markdown]
# ### 2. c)

# %%
rA = [6.6, 5.5, 5.0, 2.7, 2.3, 1.8, 0.9]
rB = [6.8, 5.8, 4.9, 3.3, 2.5, 1.8, 1.6]
theta = [(np.pi/4.0), (np.pi/2.0), (3*np.pi/4.0), (np.pi/1.0), (5*np.pi/4.0), (3*np.pi/2.0), (7*np.pi/4.0)]

# %%
plt.plot(theta, rA, color='red')
plt.plot(theta, rB, color='blue')
plt.errorbar(theta, rA, yerr=0.6, fmt='o')
# Out:
# <Container object of 3 artists>

# %% [raw]
# Normalized to observe overlap.
# Red line is Arm A as labeled in picture.
# Blue line is Arm B as labeled in picture.
# They are well within eachothers error bars.

# %% [markdown]
# ### 2 d)

# %% [raw]
# Approximating, the best fit to the each of the curves is r = -1.88 * theta + 7.5

# %% [markdown]
# ### 3. a)

# %%
rs,u,r = np.loadtxt('sdssgalaxies.dat',usecols=(2,7,9), unpack=True)

# %%
UR = u-r

# %%
plt.hist(UR, bins=200, facecolor='green');

# %% [raw]
# The majority of galaxies lie within the u-r value of 1 and 4.

# %%
less = np.where(UR < 2.2)
URless = UR[less]
more = np.where(UR > 2.2)
URmore = UR[more]

# %%
len(URless)
# Out:
# 946

# %%
len(URmore)
# Out:
# 1052

# %%
len(UR)
# Out:
# 1998

# %% [raw]
# 47.3% of the galaxies have a u-r less than 2.2
# 52.7% of the galaxies have a u-r greater than 2.2
# The r-band for galaxies with u-r > 2.2 would be fainter on average.

# %% [markdown]
# ### 3. b)

# %%
plt.ylim(0,4.2)
plt.xlim(0,0.3)
plt.plot(rs, UR, marker="o",linestyle="None",markersize=2)

# %% [markdown]
# ### 3. c)

# %% [raw]
# This graph is cut of at around 4.2 on the y-axis to look at the bulk of the data because there were some outliers far beyond 4.2. The x-axis is the redshift and the y-axis is the u-r magnitude. At first glance is might seem that the greater red shift indicates a dimmer object and thus a redder objects, but that isn't neccessarily true. As you look farther out you see more elliptical galaxies and elliptical galaxies tend to be redder and also greater in magnitude than spiral galaxies. So there is a slight bias in the graph because it is not that there is less sprial galaxies that farther you look out it's just that they are more difficult to detect. You end up seeing more elliptical galaxies making it look like there is a relationship between the redhift of galaxies and their u-r color which there really shouldn't be because the redshift due to their movement shouldn't have anything to do with their actual color.

# %% [markdown]
# ### 3. d)

# %% [markdown]
# ##  ¯\_(ツ)_/¯
